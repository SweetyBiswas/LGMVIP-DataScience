# %% [markdown]
#  ### LGMVIP - DataScience - Task1 - Iris Flowers Classification ML Project

# %% [markdown]
# ### Name - Sweety Biswas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('iris.data',names=['sepal length','sepal width','petal length','petal width','class'])

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['class'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %%
df.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# class            object
# dtype: object

# %%
print('No of Zero values in sepal length',df[df['sepal length']==0].shape[0])
# Out:
# No of Zero values in sepal length 0

# %%
print('No of Zero values in sepal width',df[df['sepal width']==0].shape[0])
# Out:
# No of Zero values in sepal width 0

# %%
print('No of Zero values in petal length',df[df['petal length']==0].shape[0])
# Out:
# No of Zero values in petal length 0

# %%
print('No of Zero values in petal width',df[df['petal width']==0].shape[0])
# Out:
# No of Zero values in petal width 0

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='PuOr')
# Out:
# <AxesSubplot:>

# %%
sns.countplot('class',data=df,palette='husl')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal length'}>,
#         <AxesSubplot:title={'center':'sepal width'}>],
#        [<AxesSubplot:title={'center':'petal length'}>,
#         <AxesSubplot:title={'center':'petal width'}>]], dtype=object)

# %%
g=sns.FacetGrid(df,col='class')
g.map(sns.scatterplot,'sepal length','sepal width')

# %%
g=sns.FacetGrid(df,col='class')
g.map(sns.scatterplot,'petal length','petal width')

# %%
sns.set_style('ticks')
sns.pairplot(df,hue='class',palette='hsv')

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
x.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: class, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape,x_test.shape
# Out:
# ((120, 4), (30, 4))

# %%
y_train.shape,y_test.shape
# Out:
# ((120,), (30,))

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.975

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
y_pred=model.predict(x_test)

# %%
Comparison_table=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
Comparison_table.head(10)
# Out:
#              Actual       Predicted
# 6       Iris-setosa     Iris-setosa
# 3       Iris-setosa     Iris-setosa
# 113  Iris-virginica  Iris-virginica
# 12      Iris-setosa     Iris-setosa
# 24      Iris-setosa     Iris-setosa
# 129  Iris-virginica  Iris-virginica
# 25      Iris-setosa     Iris-setosa
# 108  Iris-virginica  Iris-virginica
# 128  Iris-virginica  Iris-virginica
# 45      Iris-setosa     Iris-setosa

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  7,  1],
#        [ 0,  0,  8]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,cmap='brg')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(34.0, 0.5, 'Truth')
